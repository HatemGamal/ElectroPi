# %% [markdown]
# <a href="https://colab.research.google.com/github/HatemGamal/ElectroPi/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/sample_data/bank-additional-full.csv', sep = ';')
df.shape
# Out:
# (36959, 21)

# %%
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          93.994          -36.4      4.857       5191.0  no
# 1          93.994          -36.4      4.857       5191.0  no
# 2          93.994          -36.4      4.857       5191.0  no
# 3          93.994          -36.4      4.857       5191.0  no
# 4          93.994          -36.4      4.857       5191.0  no
#
# [5 rows x 21 columns]

# %%
df.info()
#No null values in the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
#  17  cons.conf.idx   41188 non-null  float64
#  18  euribor3m       41188 non-null  float64
#  19  nr.employed     41188 non-null  float64
#  20  y               41188 non-null  object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 6.6+ MB

# %%
df.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
# 1. Age
sns.histplot(df['age'], kde=True)
plt.title('Age Distribution')
plt.show()

# %%
sns.boxplot(y=df['age'])
plt.title('Boxplot of Age')
plt.show()

# %%
# 2. Job distribution
sns.countplot(data=df, x='job', order=df['job'].value_counts().index)
plt.title('Job Distribution')
plt.xticks(rotation=45)
plt.show()

# %%
# 4. Education
sns.countplot(data=df, x='education', order=df['education'].value_counts().index)
plt.title('Education Level Distribution')
plt.xticks(rotation=45)
plt.show()

# %%
# 5. Default, Housing, Loan
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))

sns.countplot(data=df, x='default', ax=ax[0])
ax[0].set_title('Credit Default Distribution')

sns.countplot(data=df, x='housing', ax=ax[1])
ax[1].set_title('Housing Loan Distribution')

sns.countplot(data=df, x='loan', ax=ax[2])
ax[2].set_title('Personal Loan Distribution')

plt.tight_layout()
plt.show()

# %%
# 6. Contact
sns.countplot(data=df, x='contact')
plt.title('Contact Type Distribution')
plt.show()

# %%
# 9. Duration
sns.histplot(df['duration'], kde=True)
plt.title('Call Duration Distribution')
plt.show()

# %%
# Different categorial features and there values in the dataset are:
print("Jobs: \n", df["job"].unique(),'\n')
print("Marital Status: \n", df['marital'].unique(),'\n')
print("Education: \n", df['education'].unique(),'\n')
print("Default on Credit: \n", df['default'].unique(),'\n')
print("Housing loan: \n", df['housing'].unique(),'\n')
print("Loan default: \n", df['loan'].unique(),'\n')
print("Contact type: \n", df['contact'].unique(),'\n')
print("Months: \n", df['month'].unique(),'\n')
print("day_of_week: \n", df['day_of_week'].unique(),'\n')
print("Poutcome: \n",df["poutcome"].unique(),'\n')
# Out:
# Jobs:
#  ['housemaid' 'services' 'admin.' 'blue-collar' 'technician' 'retired'
#  'management' 'unemployed' 'self-employed' 'unknown' 'entrepreneur'
#  'student']
#
# Marital Status:
#  ['married' 'single' 'divorced' 'unknown']
#
# Education:
#  ['basic.4y' 'high.school' 'basic.6y' 'basic.9y' 'professional.course'
#  'unknown' 'university.degree' 'illiterate']
#
# Default on Credit:
#  ['no' 'unknown' 'yes']
#
# Housing loan:
#  ['no' 'yes' 'unknown']
#
# Loan default:
#  ['no' 'yes' 'unknown']
#
# Contact type:
#  ['telephone' 'cellular']
#
# Months:
#  ['may' 'jun' 'jul' 'aug' 'oct' 'nov' 'dec' 'mar' 'apr']
#
# day_of_week:
#  ['mon' 'tue' 'wed' 'thu' 'fri']
#
# Poutcome:
#  ['nonexistent' 'failure' 'success']

# %% [markdown]
# Creating label encoders to treat all categorical variables

# %%
from sklearn.preprocessing import LabelEncoder

labelencoder_X = LabelEncoder()

# %%
df["job"] = labelencoder_X.fit_transform(df["job"])
df["marital"] = labelencoder_X.fit_transform(df["marital"])
df["education"] = labelencoder_X.fit_transform(df["education"])
df["default"] = labelencoder_X.fit_transform(df["default"])
df["housing"] = labelencoder_X.fit_transform(df["housing"])
df["loan"] = labelencoder_X.fit_transform(df["loan"])
df["contact"] = labelencoder_X.fit_transform(df["contact"])
df["month"] = labelencoder_X.fit_transform(df["month"])
df["day_of_week"] = labelencoder_X.fit_transform(df["day_of_week"])
df["poutcome"] = labelencoder_X.fit_transform(df["poutcome"])
df["y"] = labelencoder_X.fit_transform(df["y"])

# %%
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          93.994          -36.4      4.857       5191.0  no
# 1          93.994          -36.4      4.857       5191.0  no
# 2          93.994          -36.4      4.857       5191.0  no
# 3          93.994          -36.4      4.857       5191.0  no
# 4          93.994          -36.4      4.857       5191.0  no
#
# [5 rows x 21 columns]

# %%
# Generate correlation matrix heat map to check which feature has greatest influence on the output
fig, ax = plt.subplots(figsize = (20, 10))
matrix = np.triu(df.corr())
sns.heatmap(df.corr(), annot=True, fmt='.1f', vmin=-1, vmax=1, center= 0, cmap= 'coolwarm', mask=matrix)
# Out:
# <Axes: >

# %%
# Generate plots for categorical features
for col in ["job","marital","education","default","housing","loan","contact","month","day_of_week","poutcome"]:
    sns.catplot(x=col, y='y', data=df, kind='point', aspect=2, )
    plt.ylim(0, 1)

# %%
#Correlation plot
plt.figure(figsize=(14,8))
df.corr()['y'].sort_values(ascending = False).plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# From the above graph, it can be concluded that call duration has the largest effect on the target

# %% [markdown]
# # New Section

# %%
df.y.value_counts()
# Out:
# 0    34252
# 1     2706
# 2        1
# Name: y, dtype: int64

# %%
df.drop(df[df.y==2].index, inplace=True)
df.y.value_counts()
# Out:
# 0    34252
# 1     2706
# Name: y, dtype: int64

# %% [markdown]
# From the above output we can figue out that our data is imballenced.
#
# **Dealing with imballenced dataset**
#
# We can see that the data is imballenced so the output of the model will be biased. One way to move forward is:
# 1.   Undersample the data
# 2.   Oversample the data

# %%
from imblearn.over_sampling import SMOTE
oversample = SMOTE(random_state=42)
# Preparing the dataframe to be fed into undersample
df_x = df.iloc[:,:-1]
df_y = df['y']
# Getting out new data
X, y = oversample.fit_resample(df_x, df_y)
# Adding output column back to X to perform feature selection
X['y'] = y
X.head()
# Out:
#    age  job  marital  education  default  housing  loan  contact  month  \
# 0   56    3        1          0        0        0     0        1      6
# 1   57    7        1          3        1        0     0        1      6
# 2   37    7        1          3        0        2     0        1      6
# 3   40    0        1          1        0        0     0        1      6
# 4   56    7        1          3        0        0     2        1      6
#
#    day_of_week  ...  campaign  pdays  previous  poutcome  emp.var.rate  \
# 0            1  ...         1    999         0         1           1.1
# 1            1  ...         1    999         0         1           1.1
# 2            1  ...         1    999         0         1           1.1
# 3            1  ...         1    999         0         1           1.1
# 4            1  ...         1    999         0         1           1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed  y
# 0          93.994          -36.4      4.857       5191.0  0
# 1          93.994          -36.4      4.857       5191.0  0
# 2          93.994          -36.4      4.857       5191.0  0
# 3          93.994          -36.4      4.857       5191.0  0
# 4          93.994          -36.4      4.857       5191.0  0
#
# [5 rows x 21 columns]

# %%
X.y.value_counts()
# Out:
# 0    34252
# 1    34252
# Name: y, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X=df.drop('y',axis=1)
y=df['y']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)

# %%
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from sklearn.model_selection import train_test_split, KFold
import sklearn.metrics as sk
from keras.callbacks import EarlyStopping
from keras.optimizers import Adam

# Define a function to create the neural network model
def create_model():
    model = Sequential()
    model.add(Dense(256, input_dim=X_train.shape[1], activation='relu', kernel_initializer='he_uniform'))
    model.add(Dropout(0.3))
    model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
    model.add(Dropout(0.3))
    model.add(Dense(64, activation='relu', kernel_initializer='he_uniform'))
    model.add(Dropout(0.3))
    model.add(Dense(32, activation='relu', kernel_initializer='he_uniform'))
    model.add(Dropout(0.3))
    model.add(Dense(16, activation='relu', kernel_initializer='he_uniform'))
    model.add(Dropout(0.3))
    model.add(Dense(1, activation='sigmoid'))  # Output layer

    optimizer = Adam(learning_rate=0.001)
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    return model

# %%
# Create and compile the model
model = create_model()

epoch=[100,250,500]
for e in epoch:
  # Fitting the ANN to the Training set
  history=model.fit(
    X_train, y_train,
    batch_size=32,
    epochs=e,validation_split=0.3
    )
  # Predicting the Test set results
  y_pred = model.predict_classes(X_test)
  pre_score = sk.average_precision_score(y_test, y_pred)
  model.summary()
  test_results = model.evaluate(X_test, y_test)
  print("For epoch = {0}, the model test accuracy is {1}.".format(e,test_results[1]))
  print("The model test average precision score is {}.".format(pre_score))
# Out:
# Epoch 1/100
# 566/566 [==============================] - 3s 3ms/step - loss: 0.3040 - accuracy: 0.8984 - val_loss: 0.1689 - val_accuracy: 0.9286
# Epoch 2/100
# 566/566 [==============================] - 1s 2ms/step - loss: 0.1978 - accuracy: 0.9254 - val_loss: 0.1629 - val_accuracy: 0.9257
# Epoch 3/100
# 566/566 [==============================] - 1s 2ms/step - loss: 0.1824 - accuracy: 0.9245 - val_loss: 0.1605 - val_accuracy: 0.9260
# Epoch 4/100
# 566/566 [==============================] - 1s 2ms/step - loss: 0.1764 - accuracy: 0.9254 - val_loss: 0.1572 - val_accuracy: 0.9272
# Epoch 5/100
# 566/566 [==============================] - 1s 2ms/step - loss: 0.1691 - accuracy: 0.9279 - val_loss: 0.1571 - val_accuracy: 0.9259
# Epoch 6/100
# 566/566 [==============================] - 1s 2ms/step - loss: 0.1679 - accuracy: 0.9285 - val_loss: 0.1597 - val_accuracy: 0.9260
# Epoch 7/100
# 566/566 [==============================] - 1s 2ms/step - loss: 0.1655 - accuracy: 0.9259 - val_loss: 0.1583 - val_accuracy: 0.9259
# Epoch 8/100
# 566/566 [==============================] - 1s 2ms/step - loss: 0.1591 - accuracy: 0.9278 - val_loss: 0.1592 - val_accuracy: 0.9260
# Epoch 9/100
# 566/566 [==============================] - 2s 3ms/step - loss: 0.1592 - accuracy: 0.9285 - val_loss: 0.1540 - val_accuracy: 0.9285
# Epoch 10/100
# 566/566 [==============================] - 1s 2ms/step - loss: 0.1567 - accuracy: 0.9300 - val_loss: 0.1526 - val_accuracy: 0.9284
# Epoch 11/100
# 566/566 [==============================] - 1s 2ms/step - loss: 0.1528 - accuracy: 0.9287 - val_loss: 0.1572 - val_accuracy: 0.9259
# Epoch 12/100
# 566/566 [==============================] - 1s 2ms/step - loss: 0.1535 - accuracy: 0.9292 - val_loss: 0.1529 - val_accuracy: 0.9300
# Epoch 13/100
# 566/566 [==============================] - 1s 2ms/step - loss: 0.1530 - accuracy: 0.9279 - val_loss: 0.1529 - val_accuracy: 0.9293
# Epoch 14/100
# 566/566 [==============================] - 1s 2ms/step - loss: 0.1519 - accuracy: 0.9290 - val_loss: 0.1511 - val_accuracy: 0.9268
# Epoch 15/100
# 566/566 [==============================] - 1s 2ms/step - loss: 0.1485 - accuracy: 0.9305 - val_loss: 0.1538 - val_accuracy: 0.9287
# Epoch 16/100
# 566/566 [==============================] - 1s 2ms/step - loss: 0.1498 - accuracy: 0.9323 - val_loss: 0.1503 - val_accuracy: 0.9281
# Epoch 17/100
# 566/566 [==============================] - 2s 3ms/step - loss: 0.1471 - accuracy: 0.9310 - val_loss: 0.1515 - val_accuracy: 0.9280
# Epoch 18/100
# 566/566 [==============================] - 1s 2ms/step - loss: 0.1498 - accuracy: 0.9288 - val_loss: 0.1507 - val_accuracy: 0.9273
# Epoch 19/100
# 566/566 [==============================] - 1s 2ms/step - loss: 0.1472 - accuracy: 0.9298 - val_loss: 0.1491 - val_accuracy: 0.9294
# Epoch 20/100
# 566/566 [==============================] - 1s 2ms/step - loss: 0.1437 - accuracy: 0.9303 - val_loss: 0.1533 - val_accuracy: 0.9284
# Epoch 21/100
# 566/566 [==============================] - 1s 2ms/step - loss: 0.1438 - accuracy: 0.9309 - val_loss: 0.1498 - val_accuracy: 0.9294
# Epoch 22/100
# 566/566 [==============================] - 1s 2ms/step - loss: 0.1453 - accuracy: 0.9309 - val_loss: 0.1550 - val_accuracy: 0.9302
# Epoch 23/100
# 566/566 [==============================] - 1s 2ms/step - loss: 0.1428 - accuracy: 0.9311 - val_loss: 0.1510 - val_accuracy: 0.9299
# Epoch 24/100
# 566/566 [==============================] - 1s 2ms/step - loss: 0.
100
# 566/566 [==============================] - 1s 2ms/step - loss: 0.1152 - accuracy: 0.9453 - val_loss: 0.1801 - val_accuracy: 0.9258
# Epoch 79/100
# 566/566 [==============================] - 1s 2ms/step - loss: 0.1164 - accuracy: 0.9462 - val_loss: 0.1889 - val_accuracy: 0.9264
# Epoch 80/100
# 566/566 [==============================] - 1s 2ms/step - loss: 0.1139 - accuracy: 0.9467 - val_loss: 0.1777 - val_accuracy: 0.9249
# Epoch 81/100
# 566/566 [==============================] - 1s 2ms/step - loss: 0.1147 - accuracy: 0.9447 - val_loss: 0.1909 - val_accuracy: 0.9259
# Epoch 82/100
# 566/566 [==============================] - 1s 3ms/step - loss: 0.1099 - accuracy: 0.9478 - val_loss: 0.1959 - val_accuracy: 0.9255
# Epoch 83/100
# 566/566 [==============================] - 2s 3ms/step - loss: 0.1145 - accuracy: 0.9455 - val_loss: 0.1962 - val_accuracy: 0.9271
# Epoch 84/100
# 566/566 [==============================] - 2s 3ms/step - loss: 0.1125 - accuracy: 0.9484 - val_loss: 0.1727 - val_accuracy: 0.9294
# Epoch 85/100
# 566/566 [==============================] - 1s 2ms/step - loss: 0.1120 - accuracy: 0.9448 - val_loss: 0.1839 - val_accuracy: 0.9281
# Epoch 86/100
# 566/566 [==============================] - 1s 2ms/step - loss: 0.1128 - accuracy: 0.9470 - val_loss: 0.1882 - val_accuracy: 0.9286
# Epoch 87/100
# 566/566 [==============================] - 1s 2ms/step - loss: 0.1118 - accuracy: 0.9477 - val_loss: 0.1928 - val_accuracy: 0.9264
# Epoch 88/100
# 566/566 [==============================] - 1s 2ms/step - loss: 0.1107 - accuracy: 0.9486 - val_loss: 0.1857 - val_accuracy: 0.9299
# Epoch 89/100
# 566/566 [==============================] - 1s 2ms/step - loss: 0.1092 - accuracy: 0.9500 - val_loss: 0.1897 - val_accuracy: 0.9269
# Epoch 90/100
# 566/566 [==============================] - 1s 2ms/step - loss: 0.1104 - accuracy: 0.9497 - val_loss: 0.1912 - val_accuracy: 0.9284
# Epoch 91/100
# 566/566 [==============================] - 2s 3ms/step - loss: 0.1133 - accuracy: 0.9483 - val_loss: 0.1790 - val_accuracy: 0.9296
# Epoch 92/100
# 566/566 [==============================] - 2s 3ms/step - loss: 0.1119 - accuracy: 0.9481 - val_loss: 0.1804 - val_accuracy: 0.9278
# Epoch 93/100
# 566/566 [==============================] - 1s 2ms/step - loss: 0.1101 - accuracy: 0.9470 - val_loss: 0.1870 - val_accuracy: 0.9272
# Epoch 94/100
# 566/566 [==============================] - 1s 2ms/step - loss: 0.1125 - accuracy: 0.9474 - val_loss: 0.1880 - val_accuracy: 0.9254
# Epoch 95/100
# 566/566 [==============================] - 1s 3ms/step - loss: 0.1075 - accuracy: 0.9503 - val_loss: 0.2000 - val_accuracy: 0.9241
# Epoch 96/100
# 566/566 [==============================] - 1s 2ms/step - loss: 0.1069 - accuracy: 0.9513 - val_loss: 0.1809 - val_accuracy: 0.9277
# Epoch 97/100
# 566/566 [==============================] - 1s 2ms/step - loss: 0.1094 - accuracy: 0.9504 - val_loss: 0.1812 - val_accuracy: 0.9290
# Epoch 98/100
# 566/566 [==============================] - 1s 2ms/step - loss: 0.1104 - accuracy: 0.9493 - val_loss: 0.1827 - val_accuracy: 0.9282
# Epoch 99/100
# 566/566 [==============================] - 1s 3ms/step - loss: 0.1081 - accuracy: 0.9499 - val_loss: 0.1789 - val_accuracy: 0.9263
# Epoch 100/100
# 566/566 [==============================] - 2s 3ms/step - loss: 0.1073 - accuracy: 0.9490 - val_loss: 0.1905 - val_accuracy: 0.9302
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-37d66447e401> in <cell line: 38>()
#      45
#      46   # Predicting the Test set results
# ---> 47   y_pred = model.predict_classes(X_test)
#      48   pre_score = sk.average_precision_score(y_test, y_pred)
#      49   model.summary()
#
# AttributeError: 'Sequential' object has no attribute 'predict_classes'
